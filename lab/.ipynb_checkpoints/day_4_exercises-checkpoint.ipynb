# %% [markdown]
# # Day 4: Trees, Ensembles & Regularization
#
# Exercises:
# 1. Decision tree on Iris — visualize and trace
# 2. Tree depth vs overfitting
# 3. Random forest comparison
# 4. Gradient boosting on tabular data
# 5. Single tree vs random forest vs gradient boosting
# 6. L2 regularization from scratch
# 7. L1 regularization from scratch
# 8. K-fold cross-validation from scratch
# 9. Cross-validation for hyperparameter selection

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %% [markdown]
# ---
# ## Exercise 1: Decision Tree on Iris
#
# Train a decision tree on the Iris dataset, visualize it, and manually trace a prediction.

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Load data
iris = load_iris()
X_iris, y_iris = iris.data, iris.target
X_train, X_val, y_train, y_val = train_test_split(X_iris, y_iris, test_size=0.2, random_state=42)

# Train a decision tree (max_depth=3 to keep the visualization readable)
# Visualize with plot_tree(clf, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
# Pick one sample from X_val and manually trace it through the tree to verify the prediction

# Your code here:

# %% [markdown]
# ## Exercise 2: Tree Depth vs Overfitting
#
# Train trees of varying depth and observe overfitting.

# %%
# Train decision trees with max_depth = 1, 3, 5, 10, None (unlimited)
# For each, compute training accuracy and validation accuracy
# Plot both curves on the same chart (x-axis: depth, y-axis: accuracy)
# Observe: training accuracy increases with depth, but validation accuracy peaks then drops

depths = [1, 3, 5, 10, None]

# Your code here:

# %% [markdown]
# ## Exercise 3: Random Forest Comparison
#
# Train a random forest and compare against a single tree.

# %%
from sklearn.ensemble import RandomForestClassifier

# Train a single decision tree (no depth limit) and a random forest (100 trees)
# Compare:
#   - Validation accuracy
#   - Variance: run each 10 times with different random_state, compute std of accuracies
# The random forest should have similar or better accuracy with lower variance

# Your code here:

# %% [markdown]
# ## Exercise 4: Gradient Boosting on Tabular Data
#
# Train gradient boosting and tune hyperparameters.

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.datasets import fetch_california_housing, load_wine

# Use the wine dataset (classification, tabular, small)
wine = load_wine()
X_wine, y_wine = wine.data, wine.target
X_train_w, X_val_w, y_train_w, y_val_w = train_test_split(X_wine, y_wine, test_size=0.2, random_state=42)

# Train GradientBoostingClassifier with different settings:
#   - n_estimators: 50, 100, 200
#   - learning_rate: 0.01, 0.1, 1.0
# Print validation accuracy for each combination
# Observe: lower learning rate needs more estimators but often gives better results

# Your code here:

# %% [markdown]
# ## Exercise 5: Single Tree vs Random Forest vs Gradient Boosting
#
# Compare all three on the same dataset.

# %%
# Using the wine dataset from exercise 4:
# Train:
#   1. DecisionTreeClassifier (default settings)
#   2. RandomForestClassifier (100 trees)
#   3. GradientBoostingClassifier (100 trees, lr=0.1)
#
# For each, print:
#   - Training accuracy
#   - Validation accuracy
#
# Tabulate the results for easy comparison

# Your code here:

# %% [markdown]
# ---
# ## Exercise 6: L2 Regularization from Scratch
#
# Add L2 regularization to linear regression and observe coefficient shrinkage.

# %%
# Generate multi-feature data
np.random.seed(42)
n = 100
X_reg = np.random.randn(n, 5)  # 5 features
true_w = np.array([3.0, -2.0, 0.5, 0.0, 0.0])  # last two features are irrelevant
y_reg = X_reg @ true_w + np.random.randn(n) * 0.5
y_reg = y_reg.reshape(-1, 1)

# %%
# Implement gradient descent with L2 regularization:
#   Loss: L = (1/n) * ||y - Xw||^2 + lambda * ||w||^2
#   Gradient: dL/dw = (-2/n) * X.T @ (y - y_hat) + 2 * lambda * w
#
# Train with lambda = 0, 0.01, 0.1, 1.0, 10.0
# For each, print the learned weights
# Plot: for each weight index (0-4), plot its value vs lambda
# Observe: as lambda increases, all weights shrink toward zero
# The irrelevant features (true weight = 0) should shrink fastest

# Your code here:

# %% [markdown]
# ## Exercise 7: L1 Regularization from Scratch
#
# Add L1 regularization and observe feature selection (weights going exactly to zero).

# %%
# Implement gradient descent with L1 regularization:
#   Loss: L = (1/n) * ||y - Xw||^2 + lambda * ||w||_1
#   Gradient: dL/dw = (-2/n) * X.T @ (y - y_hat) + lambda * sign(w)
#
# Use the same data as exercise 6
# Train with lambda = 0, 0.01, 0.1, 1.0, 10.0
# Print the learned weights for each lambda
# Compare to L2: L1 should drive the irrelevant weights (features 3, 4) to exactly zero
# while L2 only shrinks them close to zero

# Your code here:

# %% [markdown]
# ---
# ## Exercise 8: K-Fold Cross-Validation from Scratch
#
# Implement k-fold CV manually and compare against sklearn.

# %%
from sklearn.model_selection import cross_val_score

# Implement 5-fold cross-validation manually on the Iris dataset with a DecisionTreeClassifier:
#   1. Shuffle the data indices
#   2. Split indices into 5 roughly equal folds
#   3. For each fold:
#      - Use that fold as validation, the rest as training
#      - Train a DecisionTreeClassifier
#      - Compute validation accuracy
#   4. Print each fold's accuracy and the mean ± std across folds
#
# Then compare against:
#   scores = cross_val_score(DecisionTreeClassifier(), X_iris, y_iris, cv=5)
#   print(scores.mean(), scores.std())

# Your code here:

# %% [markdown]
# ## Exercise 9: Cross-Validation for Hyperparameter Selection
#
# Use cross-validation to select the best regularization strength.

# %%
from sklearn.linear_model import Ridge

# Using the regression data from exercise 6:
# For each alpha in [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]:
#   - Run 5-fold cross-validation with Ridge(alpha=alpha)
#   - Record the mean CV score
# Plot alpha (log scale) vs mean CV score
# Print which alpha gives the best score
#
# You can use cross_val_score here since the point is hyperparameter selection,
# not reimplementing CV

# Your code here:
